# %% [markdown]
# # Introducing CNNS with TensorFlow
#
#
# In this notebook, we're going to see how we can use ```TensorFlow``` to build convolutional neural networks to work with colour image data.

# %% [markdown]
# ## Load libraries

# %%
# data tools
import os
import numpy as np
import matplotlib.pyplot as plt

# sklearn tools
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report

# tf tools
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Conv2D, 
                                     MaxPooling2D, 
                                     Activation, 
                                     Flatten, 
                                     Dense)
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import backend as K
# Out:
# 2023-04-02 11:56:11.186978: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# __Define plotting function__

# %%
def plot_history(H, epochs):
    plt.style.use("seaborn-colorblind")

    plt.figure(figsize=(12,6))
    plt.subplot(1,2,1)
    plt.plot(np.arange(0, epochs), H.history["loss"], label="train_loss")
    plt.plot(np.arange(0, epochs), H.history["val_loss"], label="val_loss", linestyle=":")
    plt.title("Loss curve")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.tight_layout()
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(np.arange(0, epochs), H.history["accuracy"], label="train_acc")
    plt.plot(np.arange(0, epochs), H.history["val_accuracy"], label="val_acc", linestyle=":")
    plt.title("Accuracy curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.tight_layout()
    plt.legend()
    plt.show()

# %% [markdown]
# __Load cifar10 data__

# %% [markdown]
# We first want to load the ```cifar-10``` dataset, normalize the values, and then binarize the labels.

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 7s 0us/step

# %% [markdown]
# **Question:** As an experiment, see what happens if you try to train the model with un-scaled images. Does it affect performance?

# %%
# normalize to same size
X_train = X_train/255
X_test = X_test/255

# %%
# create one-hot encodings
lb = LabelBinarizer() # makes numerical representations
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)

# %% [markdown]
# We'll also manually create a list of labels for when we come to print the classification report later.

# %%
# initialize label names for CIFAR-10 dataset
label_names = [
    "airplane", 
    "automobile",
    "bird", 
    "cat",
    "deer", 
    "dog",
    "frog", 
    "horse", 
    "ship", 
    "truck"]

# %% [markdown]
# ## ShallowNet

# %% [markdown]
# We're going to begin by creating one of the simplest CNN architectures with only a single convolutional layer. This type of architecture is known as the ShallowNet architecture:
# >INPUT => CONV => ReLU => FC

# %%
#initalise model
model = Sequential()

# define CONV => ReLU
model.add(
    Conv2D(
        32, # number of nodes
        (3,3), # size of kernel
        padding = "same", # 'valid' = no padding; 'same' = 0s padding
        input_shape = (32, 32, 3))) # size of input image
model.add(
    Activation(
        "relu")) # activation function relu (to avoid vanishing gradients)
          
# FC classifier
# flatten to a single image embedding array (extracted features)
model.add(
    Flatten()) 
# hidden layer
model.add(
    Dense(
        128))
model.add(
    Activation(
        "relu"))
# output layer
model.add(
    Dense(
        10))
model.add(
    Activation(
        "softmax"))

# %% [markdown]
# __Compile model__

# %% [markdown]
# We then compile our model using some of the same arguments we've already seen in different contexts.

# %%
sgd = SGD(
    learning_rate = .001) # stochastic gradient descent
model.compile(
    loss = "categorical_crossentropy",
    optimizer = sgd,
    metrics = ["accuracy"]) # optimize for accuracy

# %% [markdown]
# __Model summary__

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 128)               4194432
#
#  activation_1 (Activation)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
#  activation_2 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 4,196,618
# Trainable params: 4,196,618
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# __Plot model__

# %%
plot_model(
    model, 
    show_shapes = True, 
    show_layer_names = True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# __Train model__

# %% [markdown]
# Finally, we train the model on the data and get our predictions.

# %%
H = model.fit(
    X_train,
    y_train,
    validation_split = 0.1,
    batch_size = 32,
    epochs = 20,
    verbose = 1)
# Out:
# Epoch 1/20
# 1407/1407 [==============================] - 23s 16ms/step - loss: 2.0355 - accuracy: 0.2773 - val_loss: 1.9125 - val_accuracy: 0.3300
# Epoch 2/20
# 1407/1407 [==============================] - 22s 16ms/step - loss: 1.8562 - accuracy: 0.3534 - val_loss: 1.8527 - val_accuracy: 0.3412
# Epoch 3/20
# 1407/1407 [==============================] - 22s 16ms/step - loss: 1.7826 - accuracy: 0.3805 - val_loss: 1.7674 - val_accuracy: 0.3822
# Epoch 4/20
# 1407/1407 [==============================] - 22s 16ms/step - loss: 1.7260 - accuracy: 0.4003 - val_loss: 1.7316 - val_accuracy: 0.3998
# Epoch 5/20
# 1407/1407 [==============================] - 22s 16ms/step - loss: 1.6775 - accuracy: 0.4166 - val_loss: 1.7067 - val_accuracy: 0.4010
# Epoch 6/20
# 1407/1407 [==============================] - 22s 16ms/step - loss: 1.6370 - accuracy: 0.4302 - val_loss: 1.6506 - val_accuracy: 0.4270
# Epoch 7/20
# 1407/1407 [==============================] - 22s 16ms/step - loss: 1.6027 - accuracy: 0.4419 - val_loss: 1.6264 - val_accuracy: 0.4234
# Epoch 8/20
# 1407/1407 [==============================] - 22s 16ms/step - loss: 1.5704 - accuracy: 0.4528 - val_loss: 1.6034 - val_accuracy: 0.4434
# Epoch 9/20
# 1407/1407 [==============================] - 22s 16ms/step - loss: 1.5437 - accuracy: 0.4607 - val_loss: 1.5628 - val_accuracy: 0.4528
# Epoch 10/20
# 1407/1407 [==============================] - 22s 16ms/step - loss: 1.5190 - accuracy: 0.4666 - val_loss: 1.5471 - val_accuracy: 0.4562
# Epoch 11/20
# 1407/1407 [==============================] - 23s 16ms/step - loss: 1.4980 - accuracy: 0.4762 - val_loss: 1.5338 - val_accuracy: 0.4568
# Epoch 12/20
# 1407/1407 [==============================] - 22s 16ms/step - loss: 1.4759 - accuracy: 0.4807 - val_loss: 1.5086 - val_accuracy: 0.4734
# Epoch 13/20
# 1407/1407 [==============================] - 23s 16ms/step - loss: 1.4556 - accuracy: 0.4900 - val_loss: 1.4997 - val_accuracy: 0.4624
# Epoch 14/20
# 1407/1407 [==============================] - 22s 16ms/step - loss: 1.4358 - accuracy: 0.4947 - val_loss: 1.4841 - val_accuracy: 0.4752
# Epoch 15/20
# 1407/1407 [==============================] - 23s 16ms/step - loss: 1.4171 - accuracy: 0.5038 - val_loss: 1.4642 - val_accuracy: 0.4838
# Epoch 16/20
# 1407/1407 [==============================] - 23s 16ms/step - loss: 1.3970 - accuracy: 0.5121 - val_loss: 1.4314 - val_accuracy: 0.4966
# Epoch 17/20
# 1407/1407 [==============================] - 23s 16ms/step - loss: 1.3796 - accuracy: 0.5169 - val_loss: 1.4822 - val_accuracy: 0.4862
# Epoch 18/20
# 1407/1407 [==============================] - 23s 16ms/step - loss: 1.3624 - accuracy: 0.5226 - val_loss: 1.4201 - val_accuracy: 0.4970
# Epoch 19/20
# 1407/1407 [==============================] - 23s 16ms/step - loss: 1.3442 - accuracy: 0.5281 - val_loss: 1.3932 - val_accuracy: 0.5062
# Epoch 20/20
# 1407/1407 [==============================] - 23s 16ms/step - loss: 1.3264 - accuracy: 0.5352 - val_loss: 1.3659 - val_accuracy: 0.5184

# %% [markdown]
# __Evaluate model__

# %%
predictions = model.predict(
    X_test, 
    batch_size=32)
# Out:
# 313/313 [==============================] - 1s 4ms/step

# %%
print(
    classification_report(
        y_test.argmax(
            axis = 1),
        predictions.argmax(
            axis = 1),
        target_names = label_names))
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.53      0.64      0.58      1000
#   automobile       0.62      0.62      0.62      1000
#         bird       0.50      0.25      0.33      1000
#          cat       0.32      0.50      0.39      1000
#         deer       0.47      0.43      0.45      1000
#          dog       0.47      0.30      0.37      1000
#         frog       0.54      0.59      0.56      1000
#        horse       0.61      0.54      0.57      1000
#         ship       0.62      0.66      0.64      1000
#        truck       0.53      0.61      0.57      1000
#
#     accuracy                           0.51     10000
#    macro avg       0.52      0.51      0.51     10000
# weighted avg       0.52      0.51      0.51     10000

# %% [markdown]
# We can also use the ```plot_history()``` function available from ```TensorFlow``` to see how our model performs during training.
#
# These plots can tell us *a lot* about whether a model is under- or over-fiting the data. You read more at [this fantastic blog post](https://machinelearningmastery.com/learning-curves-for-diagnosing-machine-learning-model-performance/).
#
# Other useful blogs are [here](https://rstudio-conf-2020.github.io/dl-keras-tf/notebooks/learning-curve-diagnostics.nb.html) and there's a good video overview [here](https://youtu.be/p3CcfIjycBA).

# %%
plot_history(H, 20)
# Out:
# /tmp/ipykernel_1076/3716877966.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-colorblind")

# %% [markdown]
# ## LeNet

# %% [markdown]
# Next, we'll look at a slightly more complicated CNN architecture, known as ```LeNet``` after its creator Yann LeCun, who is now Chief AI Scientist at Meta. You can read more [here](https://en.wikipedia.org/wiki/LeNet).
# >INPUT => CONV => ReLU => MAXPOOL => CONV => ReLU => MAXPOOL => FC => ReLU => FC

# %% [markdown]
# __Define model__

# %%
# define model
model = Sequential()

# first set of layers CONV => RELU => MAXPOOL
model.add(Conv2D(32, (3,3),
                 padding="same",
                 input_shape=(32,32,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size = (2,2),
                       strides = (2,2)))

# second set of layers CONV => RELU => MAXPOOL
model.add(Conv2D(50, (5,5),
                 padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size = (2,2),
                       strides = (2,2)))

# FC => RELU
model.add(Flatten())
model.add(Dense(128))
model.add(Activation("relu"))

# softmax classifier
model.add(Dense(10))
model.add(Activation("softmax"))

# %% [markdown]
# __Compile model__

# %%
sgd = SGD(learning_rate=0.001)
model.compile(loss="categorical_crossentropy",
              optimizer=sgd,
              metrics=["accuracy"])

# %% [markdown]
# __Model summary__

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        896
#
#  activation_3 (Activation)   (None, 32, 32, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 50)        40050
#
#  activation_4 (Activation)   (None, 16, 16, 50)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 50)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 3200)              0
#
#  dense_2 (Dense)             (None, 128)               409728
#
#  activation_5 (Activation)   (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
#  activation_6 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 451,964
# Trainable params: 451,964
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# __Train model__

# %%
# train model
H = model.fit(X_train, 
              y_train, 
              validation_split=0.1, 
              batch_size=32,
              epochs=20,
              verbose=1)
# Out:
# Epoch 1/20
# 1407/1407 [==============================] - 31s 22ms/step - loss: 2.2614 - accuracy: 0.1738 - val_loss: 2.1966 - val_accuracy: 0.2178
# Epoch 2/20
# 1407/1407 [==============================] - 31s 22ms/step - loss: 2.1194 - accuracy: 0.2519 - val_loss: 2.0383 - val_accuracy: 0.2830
# Epoch 3/20
# 1407/1407 [==============================] - 31s 22ms/step - loss: 1.9729 - accuracy: 0.3043 - val_loss: 1.9318 - val_accuracy: 0.3200
# Epoch 4/20
# 1407/1407 [==============================] - 31s 22ms/step - loss: 1.8902 - accuracy: 0.3371 - val_loss: 1.8748 - val_accuracy: 0.3396
# Epoch 5/20
# 1407/1407 [==============================] - 31s 22ms/step - loss: 1.8270 - accuracy: 0.3610 - val_loss: 1.8034 - val_accuracy: 0.3658
# Epoch 6/20
# 1407/1407 [==============================] - 31s 22ms/step - loss: 1.7677 - accuracy: 0.3823 - val_loss: 1.7764 - val_accuracy: 0.3728
# Epoch 7/20
# 1407/1407 [==============================] - 31s 22ms/step - loss: 1.7101 - accuracy: 0.4042 - val_loss: 1.6878 - val_accuracy: 0.4070
# Epoch 8/20
# 1407/1407 [==============================] - 31s 22ms/step - loss: 1.6566 - accuracy: 0.4164 - val_loss: 1.9041 - val_accuracy: 0.3232
# Epoch 9/20
# 1407/1407 [==============================] - 31s 22ms/step - loss: 1.6078 - accuracy: 0.4328 - val_loss: 1.6291 - val_accuracy: 0.4004
# Epoch 10/20
# 1407/1407 [==============================] - 32s 22ms/step - loss: 1.5650 - accuracy: 0.4452 - val_loss: 1.5447 - val_accuracy: 0.4498
# Epoch 11/20
# 1407/1407 [==============================] - 32s 22ms/step - loss: 1.5246 - accuracy: 0.4571 - val_loss: 1.5327 - val_accuracy: 0.4536
# Epoch 12/20
# 1407/1407 [==============================] - 31s 22ms/step - loss: 1.4892 - accuracy: 0.4705 - val_loss: 1.5344 - val_accuracy: 0.4526
# Epoch 13/20
# 1407/1407 [==============================] - 31s 22ms/step - loss: 1.4616 - accuracy: 0.4800 - val_loss: 1.4532 - val_accuracy: 0.4802
# Epoch 14/20
# 1407/1407 [==============================] - 32s 22ms/step - loss: 1.4355 - accuracy: 0.4889 - val_loss: 1.4280 - val_accuracy: 0.4886
# Epoch 15/20
# 1407/1407 [==============================] - 32s 22ms/step - loss: 1.4151 - accuracy: 0.4966 - val_loss: 1.4239 - val_accuracy: 0.4878
# Epoch 16/20
# 1407/1407 [==============================] - 31s 22ms/step - loss: 1.3935 - accuracy: 0.5046 - val_loss: 1.4614 - val_accuracy: 0.4746
# Epoch 17/20
# 1407/1407 [==============================] - 31s 22ms/step - loss: 1.3770 - accuracy: 0.5132 - val_loss: 1.4540 - val_accuracy: 0.4856
# Epoch 18/20
# 1407/1407 [==============================] - 31s 22ms/step - loss: 1.3604 - accuracy: 0.5173 - val_loss: 1.3569 - val_accuracy: 0.5240
# Epoch 19/20
# 1407/1407 [==============================] - 31s 22ms/step - loss: 1.3437 - accuracy: 0.5265 - val_loss: 1.4250 - val_accuracy: 0.4964
# Epoch 20/20
# 1407/1407 [==============================] - 31s 22ms/step - loss: 1.3303 - accuracy: 0.5312 - val_loss: 1.3984 - val_accuracy: 0.4970

# %%
plot_history(H,20)
# Out:
# /tmp/ipykernel_1076/3716877966.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-colorblind")

# %%
predictions = model.predict(X_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
                            predictions.argmax(axis=1),
                            target_names=label_names))
# Out:
# 313/313 [==============================] - 2s 6ms/step
#               precision    recall  f1-score   support
#
#     airplane       0.50      0.68      0.57      1000
#   automobile       0.66      0.56      0.61      1000
#         bird       0.58      0.17      0.26      1000
#          cat       0.40      0.22      0.29      1000
#         deer       0.51      0.30      0.38      1000
#          dog       0.41      0.49      0.44      1000
#         frog       0.63      0.52      0.57      1000
#        horse       0.35      0.80      0.48      1000
#         ship       0.64      0.59      0.62      1000
#        truck       0.55      0.60      0.57      1000
#
#     accuracy                           0.49     10000
#    macro avg       0.52      0.49      0.48     10000
# weighted avg       0.52      0.49      0.48     10000
